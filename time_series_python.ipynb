# %%
# !pip install ts2vg
# !pip install igraph
# !pip install pycairo
# !pip install cairocffi

# %%
#importing desired libraries
from ts2vg import NaturalVG
import numpy as np
import pandas as pd
import numpy as np
from ts2vg import HorizontalVG
from matplotlib import pyplot as plt

# %%
#Task 1
#importing walking data for all 15 subjects
walking1 = pd.read_csv('acc_walking_chest-S1.csv')
walking2 = pd.read_csv('acc_walking_chest-S2.csv')
walking3 = pd.read_csv('acc_walking_chest-S3.csv')
walking4 = pd.read_csv('acc_walking_chest-S4.csv')
walking5 = pd.read_csv('acc_walking_chest-S5.csv')
walking6 = pd.read_csv('acc_walking_chest-S6.csv')
walking7 = pd.read_csv('acc_walking_chest-S7.csv')
walking8 = pd.read_csv('acc_walking_chest-S8.csv')
walking9 = pd.read_csv('acc_walking_chest-S9.csv')
walking10 = pd.read_csv('acc_walking_chest-S10.csv')
walking11= pd.read_csv('acc_walking_chest-S11.csv')
walking12= pd.read_csv('acc_walking_chest-S12.csv')
walking13= pd.read_csv('acc_walking_chest-S13.csv')
walking14= pd.read_csv('acc_walking_chest-S14.csv')
walking15= pd.read_csv('acc_walking_chest-S15.csv')

walking3
# Out:
#           id      attr_time    attr_x    attr_y    attr_z
# 0          1  1436182170018 -0.284910  9.641450  0.785298
# 1          2  1436182170038 -0.339378  9.664794  0.818817
# 2          3  1436182170057 -0.356736  9.696517  0.780510
# 3          4  1436182170076 -0.339378  9.708488  0.801459
# 4          5  1436182170096 -0.315436  9.676765  0.885855
# ...      ...            ...       ...       ...       ...
# 34112  34113  1436182852975 -0.044293  9.704897  0.160412
# 34113  34114  1436182852976  0.009577  9.740809  0.064643
# 34114  34115  1436182852977 -0.001796  9.814431 -0.008380
# 34115  34116  1436182852978 -0.025738  9.809643  0.003591
# 34116  34117  1436182852991 -0.081403  9.730036  0.065242
#
# [34117 rows x 5 columns]

# %%
#Creating a list of all walking data for 15 subjects
walking=[walking1,walking2,walking3,walking4,walking5,walking6,walking7,walking8,walking9,walking10,walking11,walking12,
        walking13,walking14,walking15]

# %%
# NVG, HVG, Average Degree, Network diameter and Average Path length for walking data for X,Y,Z Attr for all 15 subjects
d_walk_x=[]
d_walk_y=[]
d_walk_z=[]
d_walk_x_H=[]
d_walk_y_H=[]
d_walk_z_H=[]

dm_walk_x=[]
dm_walk_y=[]
dm_walk_z=[]
dm_walk_x_H=[]
dm_walk_y_H=[]
dm_walk_z_H=[]  

Ap_walk_x=[]
Ap_walk_y=[]
Ap_walk_z=[]
Ap_walk_x_H=[]
Ap_walk_y_H=[]
Ap_walk_z_H=[]  

# for loop for 15 subjects for walking
for i in range(0,len(walking)) :
    walking_x = NaturalVG()
    walking_x.build(walking[i]['attr_x'][1000:2024])
    ig_g_N_W_x = walking_x.as_igraph()
    
    print('Average Degree for Walking:',np.mean(ig_g_N_W_x.degree()))
    d_walk_x.append(np.mean(ig_g_N_W_x.degree()))
    print(d_walk_x)
    
    print('Network Diameter for Walking:',ig_g_N_W_x.diameter())
    dm_walk_x.append(ig_g_N_W_x.diameter())
    print(dm_walk_x)
    
    print('Average Path Length for Walking:',ig_g_N_W_x.average_path_length())
    Ap_walk_x.append(ig_g_N_W_x.average_path_length())
    print(Ap_walk_x)
    
    walking_y = NaturalVG()
    walking_y.build(walking[i]['attr_y'][1000:2024])
    ig_g_N_W_y = walking_y.as_igraph()
    print('Average Degree for Walking:',np.mean(ig_g_N_W_y.degree()))
    d_walk_y.append(np.mean(ig_g_N_W_y.degree()))
    print(d_walk_y)
    
    print('Network Diameter for Walking:',ig_g_N_W_y.diameter())
    dm_walk_y.append(ig_g_N_W_y.diameter())
    print(dm_walk_y)
    
    
    print('Average Path Length for Walking:',ig_g_N_W_y.average_path_length())
    Ap_walk_y.append(ig_g_N_W_y.average_path_length())
    print(Ap_walk_y)
    
    walking_z = NaturalVG()
    walking_z.build(walking[i]['attr_z'][1000:2024])
    ig_g_N_W_z = walking_z.as_igraph()
    
    print('Average Degree for Walking:',np.mean(ig_g_N_W_z.degree()))
    d_walk_z.append(np.mean(ig_g_N_W_z.degree()))
    print(d_walk_z)
    
    print('Network Diameter for Walking:',ig_g_N_W_z.diameter())
    dm_walk_z.append(ig_g_N_W_z.diameter())
    print(dm_walk_z)
    
    print('Average Path Length for Walking:',ig_g_N_W_z.average_path_length())
    Ap_walk_z.append(ig_g_N_W_z.average_path_length())
    print(Ap_walk_z)
    #HVG
    g = HorizontalVG()
    g.build(walking[i]['attr_x'][1000:2024])
    ig_g_H_W_x = g.as_igraph()
    print('HVG Average Degree for Walking:',np.mean(ig_g_H_W_x.degree()))
    d_walk_x_H.append(np.mean(ig_g_H_W_x.degree()))
    print( d_walk_x_H)
    
    print('HVG Network Diameter for Walking:',ig_g_H_W_x.diameter())
    dm_walk_x_H.append(ig_g_H_W_x.diameter())
    print(dm_walk_x_H)
    
    print('HVG Average Path Length for Walking:',ig_g_H_W_x.average_path_length())
    Ap_walk_x_H.append(ig_g_H_W_x.average_path_length())
    print(Ap_walk_x_H)
    
    g = HorizontalVG()
    g.build(walking[i]['attr_y'][1000:2024])
    ig_g_H_W_y = g.as_igraph()
    print('HVG Average Degree for Walking:',np.mean(ig_g_H_W_y.degree()))
    d_walk_y_H.append(np.mean(ig_g_H_W_y.degree()))
    print(d_walk_y_H)
    
    print('HVG Network Diameter for Walking:',ig_g_H_W_y.diameter())
    dm_walk_y_H.append(ig_g_H_W_y.diameter())
    print(dm_walk_y_H)
    
    print('HVG Average Path Length for Walking:',ig_g_H_W_y.average_path_length())
    Ap_walk_y_H.append(ig_g_H_W_y.average_path_length())
    print(Ap_walk_y_H)
    
    g = HorizontalVG()
    g.build(walking[i]['attr_z'][1000:2024])
    ig_g_H_W_z = g.as_igraph()
    print('HVG Average Degree for Walking:',np.mean(ig_g_H_W_z.degree()))
    d_walk_z_H.append(np.mean(ig_g_H_W_z.degree()))
    print(d_walk_z_H)
    
    print('HVG Network Diameter for Walking:',ig_g_H_W_z.diameter())
    dm_walk_z_H.append(ig_g_H_W_z.diameter())
    print(dm_walk_z_H)
    
    print('HVG Average Path Length for Walking:',ig_g_H_W_z.average_path_length())
    Ap_walk_z_H.append(ig_g_H_W_z.average_path_length())
    print(Ap_walk_z_H)
# Out:
# Average Degree for Walking: 11.451171875
# [11.451171875]
# Network Diameter for Walking: 10
# [10]
# Average Path Length for Walking: 4.441492164589443
# [4.441492164589443]
# Average Degree for Walking: 11.986328125
# [11.986328125]
# Network Diameter for Walking: 9
# [9]
# Average Path Length for Walking: 4.2410496089931575
# [4.2410496089931575]
# Average Degree for Walking: 8.5703125
# [8.5703125]
# Network Diameter for Walking: 10
# [10]
# Average Path Length for Walking: 4.897721545087976
# [4.897721545087976]
# HVG Average Degree for Walking: 3.958984375
# [3.958984375]
# HVG Network Diameter for Walking: 26
# [26]
# HVG Average Path Length for Walking: 11.578023811705767
# [11.578023811705767]
# HVG Average Degree for Walking: 3.951171875
# [3.951171875]
# HVG Network Diameter for Walking: 22
# [22]
# HVG Average Path Length for Walking: 10.666252367424242
# [10.666252367424242]
# HVG Average Degree for Walking: 3.95703125
# [3.95703125]
# ...

# %%
#Importing running data for all 15 subjects
running1 = pd.read_csv('acc_running_chest-S1.csv')
running2 = pd.read_csv('acc_running_chest-S2.csv')
running3 = pd.read_csv('acc_running_chest-S3.csv')
running4 = pd.read_csv('acc_running_chest-S4.csv')
running5 = pd.read_csv('acc_running_chest-S5.csv')
running6 = pd.read_csv('acc_running_chest-S6.csv')
running7 = pd.read_csv('acc_running_chest-S7.csv')
running8 = pd.read_csv('acc_running_chest-S8.csv')
running9 = pd.read_csv('acc_running_chest-S9.csv')
running10 = pd.read_csv('acc_running_chest-S10.csv')
running11= pd.read_csv('acc_running_chest-S11.csv')
running12= pd.read_csv('acc_running_chest-S12.csv')
running13= pd.read_csv('acc_running_chest-S13.csv')
running14= pd.read_csv('acc_running_chest-S14.csv')
running15= pd.read_csv('acc_running_chest-S15.csv')

running3
# Out:
#           id      attr_time    attr_x    attr_y    attr_z
# 0          1  1436183316116  0.671574  9.598354  1.347337
# 1          2  1436183316136  0.648230  9.615114  1.330578
# 2          3  1436183316156  0.669179  9.625289  1.262941
# 3          4  1436183316176  0.645836  9.642049  1.253963
# 4          5  1436183316196  0.669179  9.639056  1.267730
# ...      ...            ...       ...       ...       ...
# 37933  37934  1436184075510  0.374094  9.753978 -0.037709
# 37934  37935  1436184075560  0.389058  9.746197 -0.109535
# 37935  37936  1436184075561  0.369904  9.736021 -0.170587
# 37936  37937  1436184075579  0.411803  9.649830 -0.134075
# 37937  37938  1436184075588  0.363919  9.777321 -0.655413
#
# [37938 rows x 5 columns]

# %%
#Creating a list with running data for all 15 subjects
running=[running1,running2,running3,running4,running5,running6,running7,running8,running9,running10,running11,running12,
         running13,running14,running15]

# %%
# NVG, HVG, Average Degree, Network diameter and Average Path length for running data for X,Y,Z Attr for all 15 subjects
d_run_x=[]
d_run_y=[]
d_run_z=[]
d_run_x_H=[]
d_run_y_H=[]
d_run_z_H=[]

dm_run_x=[]
dm_run_y=[]
dm_run_z=[]
dm_run_x_H=[]
dm_run_y_H=[]
dm_run_z_H=[]  

Ap_run_x=[]
Ap_run_y=[]
Ap_run_z=[]
Ap_run_x_H=[]
Ap_run_y_H=[]
Ap_run_z_H=[]  

# for loop for 15 subjects for running
for i in range(0,len(running)) :
    running_x = NaturalVG()
    running_x.build(running[i]['attr_x'][1000:2024])
    ig_g_N_R_x = running_x.as_igraph()
    
    print('Average Degree for Running:',np.mean(ig_g_N_R_x.degree()))
    d_run_x.append(np.mean(ig_g_N_R_x.degree()))
    print(d_run_x)
    
    print('Network Diameter for Running:',ig_g_N_R_x.diameter())
    dm_run_x.append(ig_g_N_R_x.diameter())
    print(dm_run_x)
    
    print('Average Path Length for Running:',ig_g_N_R_x.average_path_length())
    Ap_run_x.append(ig_g_N_R_x.average_path_length())
    print(Ap_run_x)
    
    running_y = NaturalVG()
    running_y.build(running[i]['attr_y'][1000:2024])
    ig_g_N_R_y = running_y.as_igraph()
    print('Average Degree for Running:',np.mean(ig_g_N_R_y.degree()))
    d_run_y.append(np.mean(ig_g_N_R_y.degree()))
    print(d_run_y)
    
    print('Network Diameter for Running:',ig_g_N_R_y.diameter())
    dm_run_y.append(ig_g_N_R_y.diameter())
    print(dm_run_y)
    
    
    print('Average Path Length for Running:',ig_g_N_R_y.average_path_length())
    Ap_run_y.append(ig_g_N_R_y.average_path_length())
    print(Ap_run_y)
    
    running_z = NaturalVG()
    running_z.build(running[i]['attr_z'][1000:2024])
    ig_g_N_R_z = running_z.as_igraph()
    
    print('Average Degree for Running:',np.mean(ig_g_N_R_z.degree()))
    d_run_z.append(np.mean(ig_g_N_R_z.degree()))
    print(d_run_z)
    
    print('Network Diameter for Running:',ig_g_N_R_z.diameter())
    dm_run_z.append(ig_g_N_R_z.diameter())
    print(dm_run_z)
    
    print('Average Path Length for Running:',ig_g_N_R_z.average_path_length())
    Ap_run_z.append(ig_g_N_R_z.average_path_length())
    print(Ap_run_z)
    #HVG
    g = HorizontalVG()
    g.build(running[i]['attr_x'][1000:2024])
    ig_g_H_R_x = g.as_igraph()
    print('HVG Average Degree for Running:',np.mean(ig_g_H_R_x.degree()))
    d_run_x_H.append(np.mean(ig_g_H_R_x.degree()))
    print( d_run_x_H)
    
    print('HVG Network Diameter for Running:',ig_g_H_R_x.diameter())
    dm_run_x_H.append(ig_g_H_R_x.diameter())
    print(dm_run_x_H)
    
    print('HVG Average Path Length for Running:',ig_g_H_R_x.average_path_length())
    Ap_run_x_H.append(ig_g_H_R_x.average_path_length())
    print(Ap_run_x_H)
    
    g = HorizontalVG()
    g.build(running[i]['attr_y'][1000:2024])
    ig_g_H_R_y = g.as_igraph()
    print('HVG Average Degree for Running:',np.mean(ig_g_H_R_y.degree()))
    d_run_y_H.append(np.mean(ig_g_H_R_y.degree()))
    print(d_run_y_H)
    
    print('HVG Network Diameter for Running:',ig_g_H_R_y.diameter())
    dm_run_y_H.append(ig_g_H_R_y.diameter())
    print(dm_run_y_H)
    
    print('HVG Average Path Length for Running:',ig_g_H_R_y.average_path_length())
    Ap_run_y_H.append(ig_g_H_R_y.average_path_length())
    print(Ap_run_y_H)
    
    g = HorizontalVG()
    g.build(running[i]['attr_z'][1000:2024])
    ig_g_H_R_z = g.as_igraph()
    print('HVG Average Degree for Running:',np.mean(ig_g_H_R_z.degree()))
    d_run_z_H.append(np.mean(ig_g_H_R_z.degree()))
    print(d_run_z_H)
    
    print('HVG Network Diameter for Running:',ig_g_H_R_z.diameter())
    dm_run_z_H.append(ig_g_H_R_z.diameter())
    print(dm_run_z_H)
    
    print('HVG Average Path Length for Running:',ig_g_H_R_z.average_path_length())
    Ap_run_z_H.append(ig_g_H_R_z.average_path_length())
    print(Ap_run_z_H)
# Out:
# Average Degree for Running: 8.4140625
# [8.4140625]
# Network Diameter for Running: 9
# [9]
# Average Path Length for Running: 4.3076448710899315
# [4.3076448710899315]
# Average Degree for Running: 11.13671875
# [11.13671875]
# Network Diameter for Running: 82
# [82]
# Average Path Length for Running: 28.65194854288856
# [28.65194854288856]
# Average Degree for Running: 8.318359375
# [8.318359375]
# Network Diameter for Running: 11
# [11]
# Average Path Length for Running: 4.644368966886608
# [4.644368966886608]
# HVG Average Degree for Running: 3.962890625
# [3.962890625]
# HVG Network Diameter for Running: 22
# [22]
# HVG Average Path Length for Running: 7.543843169599218
# [7.543843169599218]
# HVG Average Degree for Running: 3.8359375
# [3.8359375]
# HVG Network Diameter for Running: 90
# [90]
# HVG Average Path Length for Running: 31.634922180474096
# [31.634922180474096]
# HVG Average Degree for Running: 3.96484375
# [3.96484375]
# HVG Network Diameter for Running: 19
# [19]
# ...

# %%
#Importing all climbing up data for all 15 subjects
climbingup1 = pd.read_csv('acc_climbingup_chest-S1.csv')
climbingup2 = pd.read_csv('acc_climbingup_chest-S2.csv')
climbingup3 = pd.read_csv('acc_climbingup_chest-S3.csv')
climbingup4 = pd.read_csv('acc_climbingup_chest-S4.csv')
climbingup5 = pd.read_csv('acc_climbingup_chest-S5.csv')
climbingup6 = pd.read_csv('acc_climbingup_chest-S6.csv')
climbingup7 = pd.read_csv('acc_climbingup_chest-S7.csv')
climbingup8 = pd.read_csv('acc_climbingup_chest-S8.csv')
climbingup9 = pd.read_csv('acc_climbingup_chest-S9.csv')
climbingup10 = pd.read_csv('acc_climbingup_chest-S10.csv')
climbingup11= pd.read_csv('acc_climbingup_chest-S11.csv')
climbingup12= pd.read_csv('acc_climbingup_chest-S12.csv')
climbingup13= pd.read_csv('acc_climbingup_chest-S13.csv')
climbingup14= pd.read_csv('acc_climbingup_chest-S14.csv')
climbingup15= pd.read_csv('acc_climbingup_chest-S15.csv')

climbingup3
# Out:
#           id      attr_time    attr_x    attr_y    attr_z
# 0          1  1436179573518  0.341772  9.678560  1.018134
# 1          2  1436179573519  0.341772  9.700109  1.018134
# 2          3  1436179573520  0.334590  9.710283  1.038485
# 3          4  1436179573521  0.335188  9.706693  1.031302
# 4          5  1436179573522  0.321422  9.643246  1.031901
# ...      ...            ...       ...       ...       ...
# 29546  29547  1436180164935  0.094571  9.849147 -0.256778
# 29547  29548  1436180164936  0.117316  9.773131 -0.524929
# 29548  29549  1436180164940 -0.140061  9.785701  0.122104
# 29549  29550  1436180164962 -0.269348  9.828796 -0.055067
# 29550  29551  1436180164985 -0.278925  9.516952 -0.357335
#
# [29551 rows x 5 columns]

# %%
#Creating a list with climbing up data for all 15 Subjects
climbingup=[climbingup1,climbingup2,climbingup3,climbingup4,climbingup5,climbingup6,climbingup7,climbingup8,climbingup9,climbingup10,climbingup11,climbingup12,
           climbingup13,climbingup14,climbingup15]

# %%
# # NVG, HVG, Average Degree, Network diameter and Average Path length for climbingup data for X,Y,Z Attr for all 15 subjects
d_climbingup_x=[]
d_climbingup_y=[]
d_climbingup_z=[]
d_climbingup_x_H=[]
d_climbingup_y_H=[]
d_climbingup_z_H=[]

dm_climbingup_x=[]
dm_climbingup_y=[]
dm_climbingup_z=[]
dm_climbingup_x_H=[]
dm_climbingup_y_H=[]
dm_climbingup_z_H=[]  

Ap_climbingup_x=[]
Ap_climbingup_y=[]
Ap_climbingup_z=[]
Ap_climbingup_x_H=[]
Ap_climbingup_y_H=[]
Ap_climbingup_z_H=[]  

# for loop for 15 subjects for climbingup
for i in range(0,len(climbingup)) :
    climbingup_x = NaturalVG()
    climbingup_x.build(climbingup[i]['attr_x'][1000:2024])
    ig_g_N_CU_x = climbingup_x.as_igraph()
    
    print('Average Degree for climbing up:',np.mean(ig_g_N_CU_x.degree()))
    d_climbingup_x.append(np.mean(ig_g_N_CU_x.degree()))
    print(d_climbingup_x)
    
    print('Network Diameter for climbing up:',ig_g_N_CU_x.diameter())
    dm_climbingup_x.append(ig_g_N_CU_x.diameter())
    print(dm_climbingup_x)
    
    print('Average Path Length for climbing up:',ig_g_N_CU_x.average_path_length())
    Ap_climbingup_x.append(ig_g_N_CU_x.average_path_length())
    print(Ap_climbingup_x)
    
    climbingup_y = NaturalVG()
    climbingup_y.build(climbingup[i]['attr_y'][1000:2024])
    ig_g_N_CU_y = climbingup_y.as_igraph()
    print('Average Degree for climbing up:',np.mean(ig_g_N_CU_y.degree()))
    d_climbingup_y.append(np.mean(ig_g_N_CU_y.degree()))
    print(d_climbingup_y)
    
    print('Network Diameter for climbing up:',ig_g_N_CU_y.diameter())
    dm_climbingup_y.append(ig_g_N_CU_y.diameter())
    print(dm_climbingup_y)
    
    
    print('Average Path Length for climbing up:',ig_g_N_CU_y.average_path_length())
    Ap_climbingup_y.append(ig_g_N_CU_y.average_path_length())
    print(Ap_climbingup_y)
    
    climbingup_z = NaturalVG()
    climbingup_z.build(climbingup[i]['attr_z'][1000:2024])
    ig_g_N_CU_z = climbingup_z.as_igraph()
    
    print('Average Degree for climbing up:',np.mean(ig_g_N_CU_z.degree()))
    d_climbingup_z.append(np.mean(ig_g_N_CU_z.degree()))
    print(d_climbingup_z)
    
    print('Network Diameter for climbing up:',ig_g_N_CU_z.diameter())
    dm_climbingup_z.append(ig_g_N_CU_z.diameter())
    print(dm_climbingup_z)
    
    print('Average Path Length for climbing up:',ig_g_N_CU_z.average_path_length())
    Ap_climbingup_z.append(ig_g_N_CU_z.average_path_length())
    print(Ap_climbingup_z)
    #HVG
    g = HorizontalVG()
    g.build(climbingup[i]['attr_x'][1000:2024])
    ig_g_H_CU_x = g.as_igraph()
    print('HVG Average Degree for climbingup:',np.mean(ig_g_H_CU_x.degree()))
    d_climbingup_x_H.append(np.mean(ig_g_H_CU_x.degree()))
    print( d_climbingup_x_H)
    
    print('HVG Network Diameter for climbingup:',ig_g_H_CU_x.diameter())
    dm_climbingup_x_H.append(ig_g_H_CU_x.diameter())
    print(dm_climbingup_x_H)
    
    print('HVG Average Path Length for climbing up:',ig_g_H_CU_x.average_path_length())
    Ap_climbingup_x_H.append(ig_g_H_CU_x.average_path_length())
    print(Ap_climbingup_x_H)
    
    g = HorizontalVG()
    g.build(climbingup[i]['attr_y'][1000:2024])
    ig_g_H_CU_y = g.as_igraph()
    print('HVG Average Degree for climbing up:',np.mean(ig_g_H_CU_y.degree()))
    d_climbingup_y_H.append(np.mean(ig_g_H_CU_y.degree()))
    print(d_climbingup_y_H)
    
    print('HVG Network Diameter for climbing up:',ig_g_H_CU_y.diameter())
    dm_climbingup_y_H.append(ig_g_H_CU_y.diameter())
    print(dm_climbingup_y_H)
    
    print('HVG Average Path Length for climbing up:',ig_g_H_CU_y.average_path_length())
    Ap_climbingup_y_H.append(ig_g_H_CU_y.average_path_length())
    print(Ap_climbingup_y_H)
    
    g = HorizontalVG()
    g.build(climbingup[i]['attr_z'][1000:2024])
    ig_g_H_CU_z = g.as_igraph()
    print('HVG Average Degree for climbing up:',np.mean(ig_g_H_CU_z.degree()))
    d_climbingup_z_H.append(np.mean(ig_g_H_CU_z.degree()))
    print(d_climbingup_z_H)
    
    print('HVG Network Diameter for climbing up:',ig_g_H_CU_z.diameter())
    dm_climbingup_z_H.append(ig_g_H_CU_z.diameter())
    print(dm_climbingup_z_H)
    
    print('HVG Average Path Length for climbing up:',ig_g_H_CU_z.average_path_length())
    Ap_climbingup_z_H.append(ig_g_H_CU_z.average_path_length())
    print(Ap_climbingup_z_H)
# Out:
# Average Degree for climbing up: 15.376953125
# [15.376953125]
# Network Diameter for climbing up: 7
# [7]
# Average Path Length for climbing up: 3.8828239552785924
# [3.8828239552785924]
# Average Degree for climbing up: 16.328125
# [16.328125]
# Network Diameter for climbing up: 11
# [11]
# Average Path Length for climbing up: 4.4813259866813295
# [4.4813259866813295]
# Average Degree for climbing up: 9.95703125
# [9.95703125]
# Network Diameter for climbing up: 10
# [10]
# Average Path Length for climbing up: 4.634183315004887
# [4.634183315004887]
# HVG Average Degree for climbingup: 3.95703125
# [3.95703125]
# HVG Network Diameter for climbingup: 35
# [35]
# HVG Average Path Length for climbing up: 15.409904233870968
# [15.409904233870968]
# HVG Average Degree for climbing up: 3.951171875
# [3.951171875]
# HVG Network Diameter for climbing up: 33
# [33]
# HVG Average Path Length for climbing up: 14.38451169965787
# [14.38451169965787]
# ...

# %%
#importing climbing down data for all 15 subjects
climbingdown1 = pd.read_csv('acc_climbingdown_chest-S1.csv')
climbingdown2 = pd.read_csv('acc_climbingdown_chest-S2.csv')
climbingdown3 = pd.read_csv('acc_climbingdown_chest-S3.csv')
climbingdown4 = pd.read_csv('acc_climbingdown_chest-S4.csv')
climbingdown5 = pd.read_csv('acc_climbingdown_chest-S5.csv')
climbingdown6 = pd.read_csv('acc_climbingdown_chest-S6.csv')
climbingdown7 = pd.read_csv('acc_climbingdown_chest-S7.csv')
climbingdown8 = pd.read_csv('acc_climbingdown_chest-S8.csv')
climbingdown9 = pd.read_csv('acc_climbingdown_chest-S9.csv')
climbingdown10 = pd.read_csv('acc_climbingdown_chest-S10.csv')
climbingdown11= pd.read_csv('acc_climbingdown_chest-S11.csv')
climbingdown12= pd.read_csv('acc_climbingdown_chest-S12.csv')
climbingdown13= pd.read_csv('acc_climbingdown_chest-S13.csv')
climbingdown14= pd.read_csv('acc_climbingdown_chest-S14.csv')
climbingdown15= pd.read_csv('acc_climbingdown_chest-S15.csv')


climbingdown3
# Out:
#           id      attr_time    attr_x    attr_y    attr_z
# 0          1  1436185163416  0.912789  9.699510  0.929549
# 1          2  1436185163433  0.915782  9.695918  0.899023
# 2          3  1436185163453  0.910994  9.680955  0.840963
# 3          4  1436185163472  0.901417  9.658808  0.867300
# 4          5  1436185163492  0.898424  9.658808  0.926556
# ...      ...            ...       ...       ...       ...
# 27738  27739  1436185718710  0.493206  9.933543 -0.201113
# 27739  27740  1436185718728  0.577601  9.835381 -0.111330
# 27740  27741  1436185718747  0.673968  9.730036 -0.085593
# 27741  27742  1436185718766  0.737414  9.706693 -0.082001
# 27742  27743  1436185718787  0.709282  9.720459 -0.124498
#
# [27743 rows x 5 columns]

# %%
#Creating a list with climbingdown data for all 15 subjects
climbingdown=[climbingdown1,climbingdown2,climbingdown3,climbingdown4,climbingdown5,climbingdown6,climbingdown7,climbingdown8,climbingdown9,climbingdown10,climbingdown11,climbingdown12,
             climbingdown13,climbingdown14,climbingdown15]

# %%
# NVG, HVG, Average Degree, Network diameter and Average Path length for climbingdown data for X,Y,Z Attr for all 15 subjects
d_climbingdown_x=[]
d_climbingdown_y=[]
d_climbingdown_z=[]
d_climbingdown_x_H=[]
d_climbingdown_y_H=[]
d_climbingdown_z_H=[]

dm_climbingdown_x=[]
dm_climbingdown_y=[]
dm_climbingdown_z=[]
dm_climbingdown_x_H=[]
dm_climbingdown_y_H=[]
dm_climbingdown_z_H=[]  

Ap_climbingdown_x=[]
Ap_climbingdown_y=[]
Ap_climbingdown_z=[]
Ap_climbingdown_x_H=[]
Ap_climbingdown_y_H=[]
Ap_climbingdown_z_H=[]  

# for loop for 15 subjects for climbingdown
for i in range(0,len(climbingdown)) :
    climbingdown_x = NaturalVG()
    climbingdown_x.build(climbingdown[i]['attr_x'][1000:2024])
    ig_g_N_CD_x = climbingdown_x.as_igraph()
    
    print('Average Degree for climbing down:',np.mean(ig_g_N_CD_x.degree()))
    d_climbingdown_x.append(np.mean(ig_g_N_CD_x.degree()))
    print(d_climbingdown_x)
    
    print('Network Diameter for climbing down:',ig_g_N_CD_x.diameter())
    dm_climbingdown_x.append(ig_g_N_CD_x.diameter())
    print(dm_climbingdown_x)
    
    print('Average Path Length for climbing down:',ig_g_N_CD_x.average_path_length())
    Ap_climbingdown_x.append(ig_g_N_CD_x.average_path_length())
    print(Ap_climbingdown_x)
    
    climbingdown_y = NaturalVG()
    climbingdown_y.build(climbingdown[i]['attr_y'][1000:2024])
    ig_g_N_CD_y = climbingdown_y.as_igraph()
    print('Average Degree for climbing down:',np.mean(ig_g_N_CD_y.degree()))
    d_climbingdown_y.append(np.mean(ig_g_N_CD_y.degree()))
    print(d_climbingdown_y)
    
    print('Network Diameter for climbing down:',ig_g_N_CD_y.diameter())
    dm_climbingdown_y.append(ig_g_N_CD_y.diameter())
    print(dm_climbingdown_y)
    
    
    print('Average Path Length for climbing down:',ig_g_N_CD_y.average_path_length())
    Ap_climbingdown_y.append(ig_g_N_CD_y.average_path_length())
    print(Ap_climbingdown_y)
    
    climbingdown_z = NaturalVG()
    climbingdown_z.build(climbingdown[i]['attr_z'][1000:2024])
    ig_g_N_CD_z = climbingdown_z.as_igraph()
    
    print('Average Degree for climbing down:',np.mean(ig_g_N_CD_z.degree()))
    d_climbingdown_z.append(np.mean(ig_g_N_CD_z.degree()))
    print(d_climbingdown_z)
    
    print('Network Diameter for climbing down:',ig_g_N_CD_z.diameter())
    dm_climbingdown_z.append(ig_g_N_CD_z.diameter())
    print(dm_climbingdown_z)
    
    print('Average Path Length for climbing down:',ig_g_N_CD_z.average_path_length())
    Ap_climbingdown_z.append(ig_g_N_CD_z.average_path_length())
    print(Ap_climbingdown_z)
    #HVG
    g = HorizontalVG()
    g.build(climbingdown[i]['attr_x'][1000:2024])
    ig_g_H_CD_x = g.as_igraph()
    print('HVG Average Degree for climbing down :',np.mean(ig_g_H_CD_x.degree()))
    d_climbingdown_x_H.append(np.mean(ig_g_H_CD_x.degree()))
    print( d_climbingdown_x_H)
    
    print('HVG Network Diameter for climbing down:',ig_g_H_CD_x.diameter())
    dm_climbingdown_x_H.append(ig_g_H_CD_x.diameter())
    print(dm_climbingdown_x_H)
    
    print('HVG Average Path Length for climbing down:',ig_g_H_CD_x.average_path_length())
    Ap_climbingdown_x_H.append(ig_g_H_CD_x.average_path_length())
    print(Ap_climbingdown_x_H)
    
    g = HorizontalVG()
    g.build(climbingdown[i]['attr_y'][1000:2024])
    ig_g_H_CD_y = g.as_igraph()
    print('HVG Average Degree for climbing down:',np.mean(ig_g_H_CD_y.degree()))
    d_climbingdown_y_H.append(np.mean(ig_g_H_CD_y.degree()))
    print(d_climbingdown_y_H)
    
    print('HVG Network Diameter for climbing down:',ig_g_H_CD_y.diameter())
    dm_climbingdown_y_H.append(ig_g_H_CD_y.diameter())
    print(dm_climbingdown_y_H)
    
    print('HVG Average Path Length for climbing down:',ig_g_H_CD_y.average_path_length())
    Ap_climbingdown_y_H.append(ig_g_H_CD_y.average_path_length())
    print(Ap_climbingdown_y_H)
    
    g = HorizontalVG()
    g.build(climbingdown[i]['attr_z'][1000:2024])
    ig_g_H_CD_z = g.as_igraph()
    print('HVG Average Degree for climbing down:',np.mean(ig_g_H_CD_z.degree()))
    d_climbingdown_z_H.append(np.mean(ig_g_H_CD_z.degree()))
    print(d_climbingdown_z_H)
    
    print('HVG Network Diameter for climbing down:',ig_g_H_CD_z.diameter())
    dm_climbingdown_z_H.append(ig_g_H_CD_z.diameter())
    print(dm_climbingdown_z_H)
    
    print('HVG Average Path Length for climbing down:',ig_g_H_CD_z.average_path_length())
    Ap_climbingdown_z_H.append(ig_g_H_CD_z.average_path_length())
    print(Ap_climbingdown_z_H)
# Out:
# Average Degree for climbing down: 15.609375
# [15.609375]
# Network Diameter for climbing down: 16
# [16]
# Average Path Length for climbing down: 6.5988151423509285
# [6.5988151423509285]
# Average Degree for climbing down: 14.087890625
# [14.087890625]
# Network Diameter for climbing down: 10
# [10]
# Average Path Length for climbing down: 4.261783663245357
# [4.261783663245357]
# Average Degree for climbing down: 9.5625
# [9.5625]
# Network Diameter for climbing down: 9
# [9]
# Average Path Length for climbing down: 4.4280112108993155
# [4.4280112108993155]
# HVG Average Degree for climbing down : 3.951171875
# [3.951171875]
# HVG Network Diameter for climbing down: 32
# [32]
# HVG Average Path Length for climbing down: 14.510884423875856
# [14.510884423875856]
# HVG Average Degree for climbing down: 3.947265625
# [3.947265625]
# HVG Network Diameter for climbing down: 28
# [28]
# HVG Average Path Length for climbing down: 12.518641556695993
# [12.518641556695993]
# ...

# %%
#Tabulating NVG, HVG, Average Degree, Network diameter and Average Path length for all activities and for for all 15 subjects 

data={'Method':['NVG']*45+['HVG']*45+['NVG']*45+['HVG']*45+['NVG']*45+['HVG']*45+['NVG']*45+['HVG']*45,
             
               
               
    'Subject':['Subject 1','Subject 2','Subject 3','Subject 4','Subject 5','Subject 6','Subject 7','Subject 8','Subject 9',
               'Subject 10','Subject 11','Subject 12','Subject 13','Subject 14','Subject 15']*24,
              
      'Accelerometer_Axis':['x']*15+['y']*15+['z']*15+['x']*15+['y']*15+['z']*15
                           +['x']*15+['y']*15+['z']*15+['x']*15+['y']*15+['z']*15
                           +['x']*15+['y']*15+['z']*15+['x']*15+['y']*15+['z']*15
                           +['x']*15+['y']*15+['z']*15+['x']*15+['y']*15+['z']*15
      
                            ,
      
     'Average Degree':d_walk_x+d_walk_y+d_walk_z+d_walk_x_H+d_walk_y_H+d_walk_z_H
                      +d_run_x+d_run_y+d_run_z+d_run_x_H+d_run_y_H+d_run_z_H
       +d_climbingup_x+d_climbingup_y+d_climbingup_z+d_climbingup_x_H+d_climbingup_y_H+d_climbingup_z_H
       +d_climbingdown_x+d_climbingdown_y+d_climbingdown_z+d_climbingdown_x_H+d_climbingdown_y_H+d_climbingdown_z_H
      ,
      
      'Network Diameter':dm_walk_x+dm_walk_y+dm_walk_z+dm_walk_x_H+dm_walk_y_H+dm_walk_z_H
                        +dm_run_x+dm_run_y+dm_run_z+dm_run_x_H+dm_run_y_H+dm_run_z_H
                        +dm_climbingup_x+dm_climbingup_y+dm_climbingup_z+dm_climbingup_x_H+dm_climbingup_y_H+dm_climbingup_z_H
                         +dm_climbingdown_x+dm_climbingdown_y+dm_climbingdown_z+dm_climbingdown_x_H+dm_climbingdown_y_H+
      dm_climbingdown_z_H,
      

      
      'Average Path Length':Ap_walk_x+Ap_walk_y+Ap_walk_z+Ap_walk_x_H+Ap_walk_y_H+Ap_walk_z_H
                            +Ap_run_x+Ap_run_y+Ap_run_z+Ap_run_x_H+Ap_run_y_H+Ap_run_z_H
                             +Ap_climbingup_x+Ap_climbingup_y+Ap_climbingup_z+Ap_climbingup_x_H+Ap_climbingup_y_H+Ap_climbingup_z_H
                           +Ap_climbingdown_x+Ap_climbingdown_y+Ap_climbingdown_z+Ap_climbingdown_x_H+Ap_climbingdown_y_H+Ap_climbingdown_z_H,
      
      'Activity':['Walking']*90+['Running']*90+['Climbingup']*90+['ClimbingDown']*90
      
                 }
df=pd.DataFrame(data)
df
# Out:
#     Method     Subject Accelerometer_Axis  Average Degree  Network Diameter  \
# 0      NVG   Subject 1                  x       11.451172                10
# 1      NVG   Subject 2                  x       10.843750                12
# 2      NVG   Subject 3                  x       12.933594                11
# 3      NVG   Subject 4                  x       10.388672                11
# 4      NVG   Subject 5                  x        9.587891                 9
# ..     ...         ...                ...             ...               ...
# 355    HVG  Subject 11                  z        3.957031                37
# 356    HVG  Subject 12                  z        3.962891                34
# 357    HVG  Subject 13                  z        3.921875                45
# 358    HVG  Subject 14                  z        3.957031                27
# 359    HVG  Subject 15                  z        3.941406                32
#
#      Average Path Length      Activity
# ...

# %%
#5.Average degree vs network diameter for Running and Walking for Attribute X and NVG
df_wc=df[((df.Activity=="Walking") | (df.Activity=="Running")) & ((df.Accelerometer_Axis=="x")& (df.Method=="NVG"))]
df_wc
groups = df_wc.groupby("Activity")
for name, group in groups:
    plt.plot(group["Average Degree"], group["Network Diameter"], marker="o", linestyle="", label=name)
    plt.legend()
    plt.xlabel("Average Degree")
    plt.ylabel("Network Diameter")

# %%
#5. Average degree vs network diameter for Running and Walking for Attribute Y and NVG
df_wc_y=df[((df.Activity=="Walking") | (df.Activity=="Running")) & ((df.Accelerometer_Axis=="y")& (df.Method=="NVG"))]
df_wc_y
groups = df_wc_y.groupby("Activity")
for name, group in groups:
    plt.plot(group["Average Degree"], group["Network Diameter"], marker="o", linestyle="", label=name)
    plt.legend()
    plt.xlabel("Average Degree")
    plt.ylabel("Network Diameter")

# %%
#5.Average degree vs network diameter for Running and Walking for Attribute Z and NVG
df_wc_z=df[((df.Activity=="Walking") | (df.Activity=="Running")) & ((df.Accelerometer_Axis=="z")& (df.Method=="NVG"))]
df_wc_z
groups = df_wc_z.groupby("Activity")
for name, group in groups:
    plt.plot(group["Average Degree"], group["Network Diameter"], marker="o", linestyle="", label=name)
    plt.legend()
    plt.xlabel("Average Degree")
    plt.ylabel("Network Diameter")

# %%
#5.Average degree vs network diameter for Running and Walking for Attribute X and HVG
df_wc_x=df[((df.Activity=="Walking") | (df.Activity=="Running")) & ((df.Accelerometer_Axis=="x")& (df.Method=="HVG"))]
df_wc_x
groups = df_wc_x.groupby("Activity")
for name, group in groups:
    plt.plot(group["Average Degree"], group["Network Diameter"], marker="o", linestyle="", label=name)
    plt.legend()
    plt.xlabel("Average Degree")
    plt.ylabel("Network Diameter")

# %%
#5.Average degree vs network diameter for Running and Walking for Attribute Y and HVG
df_wc_y=df[((df.Activity=="Walking") | (df.Activity=="Running")) & ((df.Accelerometer_Axis=="y")& (df.Method=="HVG"))]
df_wc_y
groups = df_wc_y.groupby("Activity")
for name, group in groups:
    plt.plot(group["Average Degree"], group["Network Diameter"], marker="o", linestyle="", label=name)
    plt.legend()
    plt.xlabel("Average Degree")
    plt.ylabel("Network Diameter")

# %%
#5.Average degree vs network diameter for Running and Walking for Attribute Z and HVG
df_wc_z=df[((df.Activity=="Walking") | (df.Activity=="Running")) & ((df.Accelerometer_Axis=="z")& (df.Method=="HVG"))]
df_wc_z
groups = df_wc_z.groupby("Activity")
for name, group in groups:
    plt.plot(group["Average Degree"], group["Network Diameter"], marker="o", linestyle="", label=name)
    plt.legend()
    plt.xlabel("Average Degree")
    plt.ylabel("Network Diameter")

# %%
#6.Average degree vs network diameter for Climbing UP and Climbing Down for Attribute X and NVG
df_wc_x=df[((df.Activity=="Climbingup") | (df.Activity=="ClimbingDown")) & ((df.Accelerometer_Axis=="x")& (df.Method=="NVG"))]
df_wc_x
groups = df_wc_x.groupby("Activity")
for name, group in groups:
    plt.plot(group["Average Degree"], group["Network Diameter"], marker="o", linestyle="", label=name)
    plt.legend()
    plt.xlabel("Average Degree")
    plt.ylabel("Network Diameter")

# %%
#6.Average degree vs network diameter for Climbing UP and Climbing Down for Attribute Y and NVG
df_wc_y=df[((df.Activity=="Climbingup") | (df.Activity=="ClimbingDown")) & ((df.Accelerometer_Axis=="y")& (df.Method=="NVG"))]
df_wc_y
groups = df_wc_y.groupby("Activity")
for name, group in groups:
    plt.plot(group["Average Degree"], group["Network Diameter"], marker="o", linestyle="", label=name)
    plt.legend()
    plt.xlabel("Average Degree")
    plt.ylabel("Network Diameter")

# %%
#6.Average degree vs network diameter for Climbing UP and Climbing Down for Attribute Z and NVG
df_wc_z=df[((df.Activity=="Climbingup") | (df.Activity=="ClimbingDown")) & ((df.Accelerometer_Axis=="z")& (df.Method=="NVG"))]
df_wc_z
groups = df_wc_z.groupby("Activity")
for name, group in groups:
    plt.plot(group["Average Degree"], group["Network Diameter"], marker="o", linestyle="", label=name)
    plt.legend()
    plt.xlabel("Average Degree")
    plt.ylabel("Network Diameter")

# %%
#6.Average degree vs network diameter for Climbing UP and Climbing Down for Attribute X and HVG
df_wc_x=df[((df.Activity=="Climbingup") | (df.Activity=="ClimbingDown")) & ((df.Accelerometer_Axis=="x")& (df.Method=="HVG"))]
df_wc_x
groups = df_wc_x.groupby("Activity")
for name, group in groups:
    plt.plot(group["Average Degree"], group["Network Diameter"], marker="o", linestyle="", label=name)
    plt.legend()
    plt.xlabel("Average Degree")
    plt.ylabel("Network Diameter")

# %%
#6.Average degree vs network diameter for Climbing UP and Climbing Down for Attribute Y and HVG
df_wc_y=df[((df.Activity=="Climbingup") | (df.Activity=="ClimbingDown")) & ((df.Accelerometer_Axis=="y")& (df.Method=="HVG"))]
df_wc_y
groups = df_wc_y.groupby("Activity")
for name, group in groups:
    plt.plot(group["Average Degree"], group["Network Diameter"], marker="o", linestyle="", label=name)
    plt.legend()
    plt.xlabel("Average Degree")
    plt.ylabel("Network Diameter")

# %%
#6.Average degree vs network diameter for Climbing UP and Climbing Down for Attribute Z and HVG
df_wc_z=df[((df.Activity=="Climbingup") | (df.Activity=="ClimbingDown")) & ((df.Accelerometer_Axis=="z")& (df.Method=="HVG"))]
df_wc_z
groups = df_wc_z.groupby("Activity")
for name, group in groups:
    plt.plot(group["Average Degree"], group["Network Diameter"], marker="o", linestyle="", label=name)
    plt.legend()
    plt.xlabel("Average Degree")
    plt.ylabel("Network Diameter")

# %%
#Task 2

import pandas as pd
import numpy as np

from matplotlib import pyplot as plt


def s_entropy(freq_list):
    ''' This function computes the shannon entropy of a given frequency distribution.
    USAGE: shannon_entropy(freq_list)
    ARGS: freq_list = Numeric vector representing the frequency distribution
    OUTPUT: A numeric value representing shannon's entropy'''
    freq_list = [element for element in freq_list if element != 0]
    sh_entropy = 0.0
    for freq in freq_list:
        sh_entropy += freq * np.log(freq)
    sh_entropy = -sh_entropy
    return(sh_entropy)

def ordinal_patterns(ts, embdim, embdelay):
    ''' This function computes the ordinal patterns of a time series for a given embedding dimension and embedding delay.
    USAGE: ordinal_patterns(ts, embdim, embdelay)
    ARGS: ts = Numeric vector representing the time series, embdim = embedding dimension (3<=embdim<=7 prefered range), embdelay =  embdding delay
    OUPTUT: A numeric vector representing frequencies of ordinal patterns'''
    m, t = embdim, embdelay
    x = ts if isinstance(ts, np.ndarray) else np.array(ts) 

    tmp = np.zeros((x.shape[0], m))
    for i in range(m):
        tmp[:, i] = np.roll(x, i*t)
    partition = tmp[(t*m-1):, :] 
    permutation = np.argsort(partition)
    idx = _hash(permutation)

    counts = np.zeros(np.math.factorial(m))
    for i in range(counts.shape[0]):
        counts[i] = (idx == i).sum()
    return list(counts[counts != 0].astype(int))

def _hash(x):
    m, n = x.shape
    if n == 1:
        return np.zeros(m)
    return np.sum(np.apply_along_axis(lambda y: y < x[:, 0], 0, x), axis=1) * np.math.factorial(n-1) + _hash(x[:, 1:]) 
    

def p_entropy(op):
    ordinal_pat = op
    max_entropy = np.log(len(ordinal_pat))
    p = np.divide(np.array(ordinal_pat), float(sum(ordinal_pat)))
    return(s_entropy(p)/max_entropy)

def complexity(op):
    ''' This function computes the complexity of a time series defined as: Comp_JS = Q_o * JSdivergence * pe
    Q_o = Normalizing constant
    JSdivergence = Jensen-Shannon divergence
    pe = permutation entopry
    ARGS: ordinal pattern'''
    pe = p_entropy(op)
    constant1 = (0.5+((1 - 0.5)/len(op)))* np.log(0.5+((1 - 0.5)/len(op)))
    constant2 = ((1 - 0.5)/len(op))*np.log((1 - 0.5)/len(op))*(len(op) - 1)
    constant3 = 0.5*np.log(len(op))
    Q_o = -1/(constant1+constant2+constant3)

    temp_op_prob = np.divide(op, sum(op))
    temp_op_prob2 = (0.5*temp_op_prob)+(0.5*(1/len(op)))
    JSdivergence = (s_entropy(temp_op_prob2) - 0.5 * s_entropy(temp_op_prob) - 0.5 * np.log(len(op)))
    Comp_JS = Q_o * JSdivergence * pe
    return(Comp_JS)

# %%
#importing walking data for all 15 subjects
walking1 = pd.read_csv('acc_walking_chest-S1.csv')
walking2 = pd.read_csv('acc_walking_chest-S2.csv')
walking3 = pd.read_csv('acc_walking_chest-S3.csv')
walking4 = pd.read_csv('acc_walking_chest-S4.csv')
walking5 = pd.read_csv('acc_walking_chest-S5.csv')
walking6 = pd.read_csv('acc_walking_chest-S6.csv')
walking7 = pd.read_csv('acc_walking_chest-S7.csv')
walking8 = pd.read_csv('acc_walking_chest-S8.csv')
walking9 = pd.read_csv('acc_walking_chest-S9.csv')
walking10 = pd.read_csv('acc_walking_chest-S10.csv')
walking11= pd.read_csv('acc_walking_chest-S11.csv')
walking12= pd.read_csv('acc_walking_chest-S12.csv')
walking13= pd.read_csv('acc_walking_chest-S13.csv')
walking14= pd.read_csv('acc_walking_chest-S14.csv')
walking15= pd.read_csv('acc_walking_chest-S15.csv')

# %%
#Creating a list of walking data for all 15 subjects
walking=[walking1,walking2,walking3,walking4,walking5,walking6,walking7,walking8,walking9,walking10,walking11,walking12,
        walking13,walking14,walking15]

# %%
#Calculating entropy, complexity for attribute X- walking data
k = 1
a=1024
walking_pentropy_x = []
walking_complexity_x = []



    
for x in range(1, 4):                         #for loop for signal lengths 1024,2048,4096     
    for l in range(0,len(walking)) :          #for loop for 15 subjects of walking
        for i in range(3, 7):                 #for loop for dimensions 3,4,5,6
            for j in range(1, 4):             #for loop for delays 1,2,3
                    
                        ts_walking = walking[l]['attr_x'][k:(a)] 
                        op_walking = ordinal_patterns(ts_walking, i, j) 
                        walking_pentropy_x.append(p_entropy(op_walking))
                        walking_complexity_x.append(complexity(op_walking))
                        
    a=a*2

# %%
print(walking_pentropy_x)
print(len(walking_pentropy_x))
print(walking_complexity_x)
print(len(walking_complexity_x))
# Out:
# [0.8554696579863728, 0.9603369928524934, 0.9820080185854624, 0.7941303021755467, 0.9264953818175978, 0.9572486486584779, 0.795425201063725, 0.9013076001942434, 0.9291948233012101, 0.8473492773923611, 0.9281720772668417, 0.9500207913873071, 0.890270712752508, 0.9381763149163874, 0.9471354694977125, 0.8356338351092031, 0.8955495131178749, 0.8997666216214605, 0.8251390456036454, 0.875963042897589, 0.8793940973045973, 0.8645073766603074, 0.9111899743268155, 0.9082406952166894, 0.8665235206317637, 0.9333562367836391, 0.9715517260742881, 0.8088839101782421, 0.9053042993404997, 0.9433614874263827, 0.7864013712204002, 0.883005082795413, 0.9177454948857102, 0.8387713818551121, 0.9146482546815636, 0.9403732325821557, 0.9104976851394023, 0.9923149355835528, 0.9982293047488886, 0.8622748775617052, 0.984270287370191, 0.9924714925540074, 0.8679645445487902, 0.9728549473849285, 0.9753656318087294, 0.9134992941798551, 0.9727262145822771, 0.9696516488605668, 0.9108061752076054, 0.9599693779449744, 0.
# ...

# %%
#Calculating entropy, complexity for attribute Y-walking data
p = 1
b=1024
walking_pentropy_y = []
walking_complexity_y = []
for x in range(1, 4):
    for l in range(0,len(walking)) :
        for i in range(3, 7):
            for j in range(1, 4):
                    
                        ts_walking = walking[l]['attr_y'][p:(b)] 
                        op_walking = ordinal_patterns(ts_walking, i, j) 
                        walking_pentropy_y.append(p_entropy(op_walking))
                        walking_complexity_y.append(complexity(op_walking))
                        
    b=b*2

# %%
print(walking_pentropy_y)
print(len(walking_pentropy_y))
print(walking_complexity_y)
print(len(walking_complexity_y))
# Out:
# [0.8164998887704168, 0.9249519382876825, 0.9642763582638446, 0.7381534948125947, 0.8848820434733659, 0.9441551471921936, 0.7428040646418551, 0.8690218873494323, 0.9257078105141475, 0.7946734555964525, 0.9117118367928279, 0.9421553147412465, 0.7761196886750732, 0.8812937950532285, 0.9476317777897088, 0.7020158280478199, 0.8340908848234571, 0.9019644960490583, 0.7129282663699407, 0.8107726497212411, 0.8335899770350509, 0.7556460532470158, 0.8361575234500249, 0.8534794659064414, 0.7691673824707318, 0.8702790991143555, 0.9054613320428039, 0.6858511392783708, 0.8031955220109278, 0.8498045798886114, 0.6758667751217139, 0.7710109841651884, 0.8086617942342573, 0.7296756295442285, 0.8110794884856845, 0.8422407575236498, 0.8090898128512262, 0.9284396090158149, 0.9591529674505878, 0.7406338693358782, 0.8900709090320724, 0.9365439210905507, 0.734577349670602, 0.8619203376351683, 0.9025342983101405, 0.7802042990299853, 0.8762389431453966, 0.9114133290934978, 0.8774256550567259, 0.9772720598903981
# ...

# %%
#Calculating entropy, complexity for attribute Z-walking data
q = 1
c=1024
walking_pentropy_z = []
walking_complexity_z = []
for x in range(1, 4):
    for l in range(0,len(walking)) :
        for i in range(3, 7):
            for j in range(1, 4):
                    
                        ts_walking = walking[l]['attr_z'][q:(c)] 
                        op_walking = ordinal_patterns(ts_walking, i, j) 
                        walking_pentropy_z.append(p_entropy(op_walking))
                        walking_complexity_z.append(complexity(op_walking))
                        
    c=c*2

# %%
print(walking_pentropy_z)
print(len(walking_pentropy_z))
print(walking_complexity_z)
print(len(walking_complexity_z))
# Out:
# [0.9132624206188141, 0.9864674904336568, 0.9904287023250353, 0.8690615791170515, 0.9698442993997025, 0.9771139578164502, 0.8603623152074564, 0.9474965105895692, 0.9574290480731154, 0.8958963366356659, 0.9550548015590614, 0.9632995560998233, 0.9323277252064797, 0.9190194766804487, 0.9268543118674013, 0.8928330123961667, 0.8760729637909742, 0.8742060345164285, 0.859045152905463, 0.8499287708058966, 0.8570033054514068, 0.8918511992659778, 0.8969068934332657, 0.8827317633533475, 0.8787299787504135, 0.9242920560645785, 0.8935460442327924, 0.8327760273044496, 0.8814835683451038, 0.8458885330688886, 0.8201083025045185, 0.8364317855172659, 0.8135806587548201, 0.8578402012456382, 0.8524572466048161, 0.839145952677048, 0.9546284045467103, 0.9851610717893028, 0.9776079271693953, 0.9276528236758518, 0.9715531369505698, 0.9499987194352547, 0.9137683646261264, 0.9496154956477056, 0.9195369629327133, 0.9379334347718905, 0.9481061012137861, 0.930471751141072, 0.95604774072687, 0.9921856372713059, 0.
# ...

# %%
#importing running data for all 15 subjects
running1 = pd.read_csv('acc_running_chest-S1.csv')
running2 = pd.read_csv('acc_running_chest-S2.csv')
running3 = pd.read_csv('acc_running_chest-S3.csv')
running4 = pd.read_csv('acc_running_chest-S4.csv')
running5 = pd.read_csv('acc_running_chest-S5.csv')
running6 = pd.read_csv('acc_running_chest-S6.csv')
running7 = pd.read_csv('acc_running_chest-S7.csv')
running8 = pd.read_csv('acc_running_chest-S8.csv')
running9 = pd.read_csv('acc_running_chest-S9.csv')
running10 = pd.read_csv('acc_running_chest-S10.csv')
running11= pd.read_csv('acc_running_chest-S11.csv')
running12= pd.read_csv('acc_running_chest-S12.csv')
running13 = pd.read_csv('acc_running_chest-S13.csv')
running14= pd.read_csv('acc_running_chest-S14.csv')
running15= pd.read_csv('acc_running_chest-S15.csv')

# %%
#Creating a list for running data for all 15 subjects
running=[running1,running2,running3,running4,running5,running6,running7,running8,running9,running10,running11,running12,running13,running14,
         running15]

# %%
#Calculating entropy,comlexity for attribute X- running data for all 15 subjects
k = 1
a=1024
running_pentropy_x = []
running_complexity_x = []



    
for x in range(1, 4):
    for l in range(0,len(running)) :
        for i in range(3, 7):
            for j in range(1, 4):
                    
                        ts_running = running[l]['attr_x'][k:(a)] 
                        op_running = ordinal_patterns(ts_running, i, j) 
                        running_pentropy_x.append(p_entropy(op_running))
                        running_complexity_x.append(complexity(op_running))
                        
    a=a*2

# %%
print(running_pentropy_x)
print(len(running_pentropy_x))
print(running_complexity_x)
print(len(running_complexity_x))
# Out:
# [0.9050596043606909, 0.9767098112454942, 0.9918495410955916, 0.8609787650389176, 0.9591552765669668, 0.9724110930681341, 0.8636636866095975, 0.9292910901427254, 0.9410621539738955, 0.9045389373823375, 0.9450817039416733, 0.9512832600948996, 0.9324585930152334, 0.9847138392775794, 0.9920436677604765, 0.8988534534631175, 0.9736735561473607, 0.9828822703906592, 0.8995643059762071, 0.9470033350363029, 0.9445068973154264, 0.9289292043479362, 0.949264259310232, 0.93892734241112, 0.9315231332228303, 0.9808035751141918, 0.988483459899107, 0.8934098958549581, 0.9659715669771952, 0.9715667239079351, 0.8808735280937315, 0.9401097513130153, 0.9474651515625003, 0.9186196800821312, 0.9488202041803951, 0.9554143759635444, 0.9573982172582975, 0.9927155904998399, 0.9975138558265771, 0.9306949814632454, 0.9887947120842947, 0.9912105945132875, 0.9160294871057947, 0.9774703402998937, 0.9747358195692066, 0.9402228616905722, 0.9753101132669557, 0.9713049792742445, 0.898511370274159, 0.9671343518689508, 0.
# ...

# %%
#Calculating entropy,comlexity for attribute Y- running data for all 15 subjects
p = 1
b=1024
running_pentropy_y = []
running_complexity_y = []
for x in range(1, 4):
    for l in range(0,len(running)) :
        for i in range(3, 7):
            for j in range(1, 4):
                    
                        ts_running = running[l]['attr_y'][p:(b)] 
                        op_running = ordinal_patterns(ts_running, i, j) 
                        running_pentropy_y.append(p_entropy(op_running))
                        running_complexity_y.append(complexity(op_running))
                        
    b=b*2

# %%
print(running_pentropy_y)
print(len(running_pentropy_y))
print(running_complexity_y)
print(len(running_complexity_y))
# Out:
# [0.7156318709935302, 0.8140336392657765, 0.8412208347103411, 0.6415698521760784, 0.7326802756661642, 0.7733299780079578, 0.6365925113897897, 0.716380109994268, 0.7540840720273614, 0.6817733586221539, 0.7682165693717015, 0.8007773116368399, 0.7446397537058165, 0.8705441547929552, 0.9069011553301854, 0.6601441280838641, 0.8060504970553509, 0.8535746742733001, 0.6540494369508563, 0.7979593822010628, 0.8028664391842218, 0.6988240210546125, 0.8333846892502114, 0.825913837561687, 0.746892007647809, 0.8488993927199674, 0.9207089952576952, 0.6594786233982552, 0.7982188708892596, 0.8779811562474517, 0.6577238363188611, 0.7621644722261587, 0.8288902305689906, 0.6992214771207266, 0.7883176832611779, 0.8404209556380425, 0.852482488904965, 0.9526876792367349, 0.9640955652877956, 0.8023742174388424, 0.9246214003019183, 0.9437151300811722, 0.77618138523631, 0.889723752017666, 0.9012487228430883, 0.8087811282219253, 0.8932366366113123, 0.9085432157047523, 0.8429933433579018, 0.9266394363674743, 0.94
# ...

# %%
#Calculating entropy,comlexity for attribute Z- running data for all 15 subjects
q = 1
c=1024
running_pentropy_z = []
running_complexity_z = []
for x in range(1, 4):
    for l in range(0,len(running)) :
        for i in range(3, 7):
            for j in range(1, 4):
                    
                        ts_running = running[l]['attr_z'][q:(c)] 
                        op_running = ordinal_patterns(ts_running, i, j) 
                        running_pentropy_z.append(p_entropy(op_running))
                        running_complexity_z.append(complexity(op_running))
                        
    c=c*2

# %%
print(running_pentropy_z)
print(len(running_pentropy_z))
print(running_complexity_z)
print(len(running_complexity_z))
# Out:
# [0.9253695501626789, 0.990029309917877, 0.9921505084445296, 0.8882085565780637, 0.9822709087051185, 0.9773177190326324, 0.8894122343202066, 0.956468910095602, 0.9416539754716476, 0.9255768258852034, 0.9558646312644365, 0.951293946697939, 0.9577874805105697, 0.9899626289218451, 0.9853689255021114, 0.9326264990907974, 0.973786579144284, 0.966298868856054, 0.9140976961991651, 0.9410436370283964, 0.9354625210471842, 0.9340656456163554, 0.9490033441731133, 0.9446398016378196, 0.955759434415606, 0.992677486370861, 0.9965408348448329, 0.928593935065984, 0.9891148912670846, 0.9838092604058748, 0.9138418892104375, 0.966235829092179, 0.9621986850302576, 0.9487565745010134, 0.961856879249044, 0.9617055043531045, 0.973001030818776, 0.9975333398607198, 0.9912050958468756, 0.9537323508918749, 0.9903769856360121, 0.9823323659481739, 0.9448219416918516, 0.9759416830308946, 0.9690253721423259, 0.9604991922771634, 0.9722201281021483, 0.9688776849716523, 0.9507952376938412, 0.9981143880855163, 0.994952
# ...

# %%
#Importing climbing up data for all 15 subjects
climbingup1 = pd.read_csv('acc_climbingup_chest-S1.csv')
climbingup2 = pd.read_csv('acc_climbingup_chest-S2.csv')
climbingup3 = pd.read_csv('acc_climbingup_chest-S3.csv')
climbingup4 = pd.read_csv('acc_climbingup_chest-S4.csv')
climbingup5 = pd.read_csv('acc_climbingup_chest-S5.csv')
climbingup6 = pd.read_csv('acc_climbingup_chest-S6.csv')
climbingup7 = pd.read_csv('acc_climbingup_chest-S7.csv')
climbingup8 = pd.read_csv('acc_climbingup_chest-S8.csv')
climbingup9 = pd.read_csv('acc_climbingup_chest-S9.csv')
climbingup10 = pd.read_csv('acc_climbingup_chest-S10.csv')
climbingup11= pd.read_csv('acc_climbingup_chest-S11.csv')
climbingup12= pd.read_csv('acc_climbingup_chest-S12.csv')
climbingup13 = pd.read_csv('acc_climbingup_chest-S13.csv')
climbingup14= pd.read_csv('acc_climbingup_chest-S14.csv')
climbingup15= pd.read_csv('acc_climbingup_chest-S15.csv')

# %%
#Creating a list of with climbing up data
climbingup=[climbingup1,climbingup2,climbingup3,climbingup4,climbingup5,climbingup6,climbingup7,climbingup8,climbingup9,
           climbingup10,climbingup11,climbingup12,climbingup13,climbingup14,climbingup15]

# %%
#Calculating entropy,complexity for attribute X- climbing up data
k = 1
a=1024
climbingup_pentropy_x = []
climbingup_complexity_x = []



    
for x in range(1, 4):
    for l in range(0,len(climbingup)) :
        for i in range(3, 7):
            for j in range(1, 4):
                    
                        ts_climbingup = climbingup[l]['attr_x'][k:(a)] 
                        op_climbingup = ordinal_patterns(ts_climbingup, i, j) 
                        climbingup_pentropy_x.append(p_entropy(op_climbingup))
                        climbingup_complexity_x.append(complexity(op_climbingup))
                        
    a=a*2

# %%
print(climbingup_pentropy_x)
print(len(climbingup_pentropy_x))
print(climbingup_complexity_x)
print(len(climbingup_complexity_x))
# Out:
# [0.8955923114113723, 0.9564011806860636, 0.978449173350458, 0.8468802026532463, 0.932372659885812, 0.9620252272209766, 0.8231664143464308, 0.9119346745675688, 0.9409151590922927, 0.8614763283960547, 0.9322648985124361, 0.9538439454335367, 0.8803303758423222, 0.9471094295359562, 0.9737070061095183, 0.8222360024133621, 0.9185264708124069, 0.9509732466975395, 0.8125312888832479, 0.8953574740039103, 0.9334344177785192, 0.8633668239595428, 0.9304623892650082, 0.9502009200639816, 0.897240674536454, 0.9539570097763985, 0.9501210972126058, 0.8464817817036754, 0.9168380838955418, 0.9182473150408402, 0.8274245037252129, 0.8909502943754721, 0.9013359799688687, 0.8638861559035738, 0.9152959744864808, 0.9357540529453628, 0.9149870519949516, 0.9765262675177911, 0.9912095061921076, 0.8709625316901275, 0.9634602094902697, 0.9784966652736202, 0.8568167017682286, 0.9457048692964429, 0.955746087284557, 0.9029289722914573, 0.9516320802057727, 0.9581065841903647, 0.9106922686533908, 0.9672553058612129, 0
# ...

# %%
#Calculating entropy,complexity for attribute Y- climbing up data
p = 1
b=1024
climbingup_pentropy_y = []
climbingup_complexity_y = []
for x in range(1, 4):
    for l in range(0,len(climbingup)) :
        for i in range(3, 7):
            for j in range(1, 4):
                    
                        ts_climbingup = climbingup[l]['attr_y'][p:(b)] 
                        op_climbingup = ordinal_patterns(ts_climbingup, i, j) 
                        climbingup_pentropy_y.append(p_entropy(op_climbingup))
                        climbingup_complexity_y.append(complexity(op_climbingup))
                        
    b=b*2

# %%
print(climbingup_pentropy_y)
print(len(climbingup_pentropy_y))
print(climbingup_complexity_y)
print(len(climbingup_complexity_y))
# Out:
# [0.8513252860871319, 0.9521299376704618, 0.9792499433199517, 0.7923127184301606, 0.9284022277891915, 0.9646831549423751, 0.7758850419566592, 0.9076533465774475, 0.9398325486240547, 0.8157358241869579, 0.9288841348973843, 0.9378629037335025, 0.7877724833197249, 0.9043074802091559, 0.9548063317391717, 0.7102381121558315, 0.8615886647946936, 0.9177966018774456, 0.6970244989714414, 0.8440302634268783, 0.8751155557060573, 0.7523088410536249, 0.8724406569045219, 0.8923322899594782, 0.7817748097437018, 0.8755867270350522, 0.9166357653316434, 0.6917468222878241, 0.8213448636038237, 0.8669813112756689, 0.6838190929917598, 0.7825911560197661, 0.8269926456758969, 0.7322128978829203, 0.8094331468341247, 0.8550356362309962, 0.8524033427064908, 0.9025028727826714, 0.9356379134022345, 0.7791151210806517, 0.855003040976421, 0.8967668496000315, 0.7670238977387053, 0.8302066530475215, 0.8664677212472309, 0.804510269125525, 0.859652679381906, 0.8959993698420461, 0.863159887843492, 0.9544095679142488, 0
# ...

# %%
#Calculating entropy,complexity for attribute Z- climbing up data
q = 1
c=1024
climbingup_pentropy_z = []
climbingup_complexity_z = []
for x in range(1, 4):
    for l in range(0,len(climbingup)) :
        for i in range(3, 7):
            for j in range(1, 4):
                    
                        ts_climbingup = climbingup[l]['attr_z'][q:(c)] 
                        op_climbingup = ordinal_patterns(ts_climbingup, i, j) 
                        climbingup_pentropy_z.append(p_entropy(op_climbingup))
                        climbingup_complexity_z.append(complexity(op_climbingup))
                        
    c=c*2

# %%
print(climbingup_pentropy_z)
print(len(climbingup_pentropy_z))
print(climbingup_complexity_z)
print(len(climbingup_complexity_z))
# Out:
# [0.9234576625900411, 0.9887186898977829, 0.9875959278920858, 0.883825603367904, 0.9779280846948514, 0.9723485171096873, 0.871921058438369, 0.957062945704617, 0.9559681688956273, 0.9055978086420943, 0.9586543307389183, 0.9613201587317677, 0.9010180502056776, 0.9474441095407071, 0.9646228991562917, 0.8585561419955975, 0.9172519289424906, 0.9389624697092587, 0.8335007076607063, 0.8918293604278036, 0.9187096277163892, 0.8684985435407371, 0.920659667921521, 0.9439017905896206, 0.9112426482836347, 0.9465104045234892, 0.9340220240684961, 0.8670309799791024, 0.9011064722656653, 0.8920675821159411, 0.8390171588992174, 0.8659568475466612, 0.8655049368210748, 0.8674303947361678, 0.8908350661151017, 0.8976565563791895, 0.9245943804354254, 0.9530858979040592, 0.9607478179798913, 0.885137540518693, 0.920214052545976, 0.9307358436133459, 0.8572623654354025, 0.8921534153667199, 0.9026272859836955, 0.888226986443936, 0.9074598595460822, 0.9271564158934288, 0.9099607219574114, 0.9576898144705797, 0.95
# ...

# %%
#Importing climbing down data for all 15 subjects
climbingdown1 = pd.read_csv('acc_climbingdown_chest-S1.csv')
climbingdown2 = pd.read_csv('acc_climbingdown_chest-S2.csv')
climbingdown3 = pd.read_csv('acc_climbingdown_chest-S3.csv')
climbingdown4 = pd.read_csv('acc_climbingdown_chest-S4.csv')
climbingdown5 = pd.read_csv('acc_climbingdown_chest-S5.csv')
climbingdown6 = pd.read_csv('acc_climbingdown_chest-S6.csv')
climbingdown7 = pd.read_csv('acc_climbingdown_chest-S7.csv')
climbingdown8 = pd.read_csv('acc_climbingdown_chest-S8.csv')
climbingdown9 = pd.read_csv('acc_climbingdown_chest-S9.csv')
climbingdown10 = pd.read_csv('acc_climbingdown_chest-S10.csv')
climbingdown11= pd.read_csv('acc_climbingdown_chest-S11.csv')
climbingdown12= pd.read_csv('acc_climbingdown_chest-S12.csv')
climbingdown13= pd.read_csv('acc_climbingdown_chest-S13.csv')
climbingdown14= pd.read_csv('acc_climbingdown_chest-S14.csv')
climbingdown15= pd.read_csv('acc_climbingdown_chest-S15.csv')

# %%
#Creating a list with climbing down data for all 15 subjects
climbingdown=[climbingdown1,climbingdown2,climbingdown3,climbingdown4,climbingdown5,climbingdown6,climbingdown7,climbingdown8,climbingdown9,
             climbingdown10,climbingdown11,climbingdown12,climbingdown13,climbingdown14,climbingdown15]

# %%
#Calculating entropy,complexity for attribute X- climbing down data for all 15 subjects
k = 1
a=1024
climbingdown_pentropy_x = []
climbingdown_complexity_x = []



    
for x in range(1, 4):
    for l in range(0,len(climbingdown)) :
        for i in range(3, 7):
            for j in range(1, 4):
                    
                        ts_climbingdown = climbingdown[l]['attr_x'][k:(a)] 
                        op_climbingdown = ordinal_patterns(ts_climbingdown, i, j) 
                        climbingdown_pentropy_x.append(p_entropy(op_climbingdown))
                        climbingdown_complexity_x.append(complexity(op_climbingdown))
                        
    a=a*2

# %%
print(climbingdown_pentropy_x)
print(len(climbingdown_pentropy_x))
print(climbingdown_complexity_x)
print(len(climbingdown_complexity_x))
# Out:
# [0.8641586878892421, 0.9606770642470636, 0.9850362193406802, 0.8072645210508204, 0.93709807754818, 0.9757424948084702, 0.7983933683405388, 0.9138462851917627, 0.9613216060424159, 0.8478491455755977, 0.93897472756956, 0.9653821438769882, 0.9196837572781303, 0.9837189407079875, 0.9985494009025793, 0.8781889752608903, 0.9738353600082914, 0.9933429207365974, 0.8738369621501004, 0.9624598998556945, 0.9818761436087542, 0.9123977501392029, 0.9707570683174619, 0.9765665562295334, 0.9011440249079313, 0.9808781199058658, 0.9909202972434925, 0.8603847457829661, 0.9660028794702947, 0.986192005826759, 0.8435988318061689, 0.9503879579277489, 0.9707577997156458, 0.88542939212225, 0.9615862411100026, 0.9700909239822977, 0.9049783269822698, 0.9857331604457273, 0.9934350973710729, 0.8511825615945952, 0.9764202226725713, 0.9880850253712846, 0.8443886398722735, 0.9647708586441802, 0.9762935332525857, 0.898924744592115, 0.9684328889928628, 0.972626461068866, 0.9036540643034171, 0.9753193191037525, 0.9963
# ...

# %%
#Calculating entropy,complexity for attribute Y- climbing down data for all 15 subjects
p = 1
b=1024
climbingdown_pentropy_y = []
climbingdown_complexity_y = []
for x in range(1, 4):
    for l in range(0,len(climbingdown)) :
        for i in range(3, 7):
            for j in range(1, 4):
                    
                        ts_climbingdown = climbingdown[l]['attr_y'][p:(b)] 
                        op_climbingdown = ordinal_patterns(ts_climbingdown, i, j) 
                        climbingdown_pentropy_y.append(p_entropy(op_climbingdown))
                        climbingdown_complexity_y.append(complexity(op_climbingdown))
                        
    b=b*2

# %%
print(climbingdown_pentropy_y)
print(len(climbingdown_pentropy_y))
print(climbingdown_complexity_y)
print(len(climbingdown_complexity_y))
# Out:
# [0.8707084042990949, 0.9608400387630172, 0.9858108787193159, 0.8174572715719973, 0.9355427765468438, 0.9780809015212675, 0.8005074452006207, 0.9271468537665679, 0.9608032124667318, 0.8454637538567594, 0.9430763718553336, 0.9663934966105628, 0.8691450090227615, 0.9630315379686155, 0.9933385657526398, 0.8159803752894795, 0.9464126084037534, 0.984201689843352, 0.7993588690332456, 0.9332259305624044, 0.9664670343624088, 0.8466071982699016, 0.9446634610532849, 0.965783314590764, 0.842507237002554, 0.954257686593922, 0.9781501817967503, 0.7755637566557172, 0.9294512854968663, 0.963272009824108, 0.7774088990397071, 0.9055281714273659, 0.9419661930325572, 0.8255644425910054, 0.9231372312215141, 0.9509384852581462, 0.8328925513669163, 0.9352092125123462, 0.9707410931615638, 0.7725531024784449, 0.9062668302781837, 0.9462253910005145, 0.7772120035433321, 0.8802697262675536, 0.9235535410619421, 0.8194612301934391, 0.9092298457149164, 0.9406429961780611, 0.8610622630289199, 0.9446838406775636, 0.
# ...

# %%
#Calculating entropy,complexity for attribute Z- climbing down data for all 15 subjects
q = 1
c=1024
climbingdown_pentropy_z = []
climbingdown_complexity_z = []
for x in range(1, 4):
    for l in range(0,len(climbingdown)) :
        for i in range(3, 7):
            for j in range(1, 4):
                    
                        ts_climbingdown = climbingdown[l]['attr_z'][q:(c)] 
                        op_climbingdown = ordinal_patterns(ts_climbingdown, i, j) 
                        climbingdown_pentropy_z.append(p_entropy(op_climbingdown))
                        climbingdown_complexity_z.append(complexity(op_climbingdown))
                        
    c=c*2

# %%
print(climbingdown_pentropy_z)
print(len(climbingdown_pentropy_z))
print(climbingdown_complexity_z)
print(len(climbingdown_complexity_z))
# Out:
# [0.865938171115169, 0.9856350301439821, 0.9992032841032561, 0.7971268784701597, 0.9776383207924279, 0.9933881675440309, 0.8078500335318064, 0.9577155117818629, 0.9786509908860385, 0.8772525276851875, 0.963914451978599, 0.970442625836387, 0.9669380735416008, 0.9893805696433922, 0.9919555783940807, 0.9471308291613716, 0.9783577084108058, 0.9811347099058954, 0.9304205953005557, 0.9670369940727802, 0.9632276670305132, 0.9484576512125207, 0.9683284491379794, 0.9671728779025169, 0.9459794215416844, 0.997874958386247, 0.9955431270119008, 0.9154741754954075, 0.9894084416878388, 0.9882132888080923, 0.8971495790226691, 0.9715491177644037, 0.9732844345508266, 0.9360133534743524, 0.969179184571682, 0.973456428369145, 0.9370799188703379, 0.9926801266182126, 0.9963235972450325, 0.9066295993085075, 0.9837161472813513, 0.989337310406402, 0.8974694607978143, 0.9673261431195287, 0.9786822597380546, 0.9288838248834703, 0.9714036453537817, 0.978527785793057, 0.924404600043532, 0.9687443369102401, 0.9861
# ...

# %%
#Tabulating results by varying parameters - embedded dimension, embedded delay and signal length for all activities and for all 15 subjects
s=['Subject 1']*12+['Subject 2']*12+['Subject 3']*12+['Subject 4']*12+['Subject 5']*12+['Subject 6']*12+['Subject 7']*12+['Subject 8']*12+['Subject 9']*12+['Subject 10']*12+['Subject 11']*12+['Subject 12']*12+['Subject 13']*12+['Subject 14']*12+['Subject 15']*12

d=[3]*3+[4]*3+[5]*3+[6]*3

l=[1024]*36+[2048]*36+[4096]*36

data={'Subject' :  s*9+s*9+s*9+s*9,
    
      
      'Accelerometer_axis':['x']*540+['y']*540+['z']*540
      +['x']*540+['y']*540+['z']*540+['x']*540+['y']*540+['z']*540+['x']*540+['y']*540+['z']*540,
      
     'Signal_Length':l*15+l*15+l*15+l*15,
                  
      'Dimension':d*135+d*135+d*135+d*135,
      
      'Delay':[1,2,3]*540+[1,2,3]*540+[1,2,3]*540+[1,2,3]*540,
      
      'Permutation Entropy': walking_pentropy_x+walking_pentropy_y+walking_pentropy_z
                              + running_pentropy_x+running_pentropy_y+running_pentropy_z
                             +climbingup_pentropy_x+climbingup_pentropy_y+climbingup_pentropy_z
                              + climbingdown_pentropy_x+climbingdown_pentropy_y+climbingdown_pentropy_z,
      'Complexity': walking_complexity_x+walking_complexity_y+walking_complexity_z
                    +running_complexity_x+running_complexity_y+running_complexity_z
                    +climbingup_complexity_x+climbingup_complexity_y+climbingup_complexity_z
                    +climbingdown_complexity_x+climbingdown_complexity_y+climbingdown_complexity_z,
     'Activity' :['Walking']*1620+['Running']*1620+['Climbingup']*1620+['ClimbingDown']*1620
     
   }
     
df=pd.DataFrame(data)
df
# Out:
#          Subject Accelerometer_axis  Signal_Length  Dimension  Delay  \
# 0      Subject 1                  x           1024          3      1
# 1      Subject 1                  x           1024          3      2
# 2      Subject 1                  x           1024          3      3
# 3      Subject 1                  x           1024          4      1
# 4      Subject 1                  x           1024          4      2
# ...          ...                ...            ...        ...    ...
# 6475  Subject 15                  z           4096          5      2
# 6476  Subject 15                  z           4096          5      3
# 6477  Subject 15                  z           4096          6      1
# 6478  Subject 15                  z           4096          6      2
# 6479  Subject 15                  z           4096          6      3
#
#       Permutation Entropy  Complexity      Activity
# 0                0.855470    0.119549       Walking
# ...

# %%
#3.permutation entropy vs complexity for Delay=1, Dimension 3 and Signal Length 4096 for Walking, Running Attr x 
df_wc=df[
      ((df.Activity=="Walking")|(df.Activity=="Running"))&(df.Accelerometer_axis=="x")&(df.Delay==1)&(df.Dimension==3)&(df.Signal_Length==4096)
          ]
df_wc
groups = df_wc.groupby("Activity")
for name, group in groups:
    plt.plot(group["Permutation Entropy"], group["Complexity"], marker="o", linestyle="", label=name,)
    plt.legend()
    plt.xlabel("Permutation Entropy")
    plt.ylabel("Complexity")

# %%
#3.permutation entropy vs complexity for Delay=1, Dimension 3 and Signal Length 4096 for Walking, Running Attr y 
df_wc=df[
      ((df.Activity=="Walking")|(df.Activity=="Running"))&(df.Accelerometer_axis=="y")&(df.Delay==1)&(df.Dimension==3)&(df.Signal_Length==4096)
          ]
df_wc
groups = df_wc.groupby("Activity")
for name, group in groups:
    plt.plot(group["Permutation Entropy"], group["Complexity"], marker="o", linestyle="", label=name)
    plt.legend()
    plt.xlabel("Permutation Entropy")
    plt.ylabel("Complexity")

# %%
#3.permutation entropy vs complexity for Delay=1, Dimension 3 and Signal Length 4096 for Walking, Running Attr z 
df_wc=df[
      ((df.Activity=="Walking")|(df.Activity=="Running"))&(df.Accelerometer_axis=="z")&(df.Delay==1)&(df.Dimension==3)&(df.Signal_Length==4096)
          ]
df_wc
groups = df_wc.groupby("Activity")
for name, group in groups:
    plt.plot(group["Permutation Entropy"], group["Complexity"], marker="o", linestyle="", label=name)
    plt.legend()
    plt.xlabel("Permutation Entropy")
    plt.ylabel("Complexity")

# %%
#3.permutation entropy vs complexity for Delay=1, Dimension 4 and Signal Length 4096 for Walking, Running Attr x 
df_wc=df[
      ((df.Activity=="Walking")|(df.Activity=="Running"))&(df.Accelerometer_axis=="x")&(df.Delay==1)&(df.Dimension==4)&(df.Signal_Length==4096)
          ]
df_wc
groups = df_wc.groupby("Activity")
for name, group in groups:
    plt.plot(group["Permutation Entropy"], group["Complexity"], marker="o", linestyle="", label=name)
    plt.legend()
    plt.xlabel("Permutation Entropy")
    plt.ylabel("Complexity")

# %%
#3.permutation entropy vs complexity for Delay=1, Dimension 4 and Signal Length 4096 for Walking, Running Attr y 
df_wc=df[
      ((df.Activity=="Walking")|(df.Activity=="Running"))&(df.Accelerometer_axis=="y")&(df.Delay==1)&(df.Dimension==4)&(df.Signal_Length==4096)
          ]
df_wc
groups = df_wc.groupby("Activity")
for name, group in groups:
    plt.plot(group["Permutation Entropy"], group["Complexity"], marker="o", linestyle="", label=name)
    plt.legend()
    plt.xlabel("Permutation Entropy")
    plt.ylabel("Complexity")

# %%
#3.permutation entropy vs complexity for Delay=1, Dimension 4 and Signal Length 4096 for Walking, Running Attr z
df_wc=df[
      ((df.Activity=="Walking")|(df.Activity=="Running"))&(df.Accelerometer_axis=="z")&(df.Delay==1)&(df.Dimension==4)&(df.Signal_Length==4096)
          ]
df_wc
groups = df_wc.groupby("Activity")
for name, group in groups:
    plt.plot(group["Permutation Entropy"], group["Complexity"], marker="o", linestyle="", label=name)
    plt.legend()
    plt.xlabel("Permutation Entropy")
    plt.ylabel("Complexity")

# %%
#3.permutation entropy vs complexity for Delay=1, Dimension 5 and Signal Length 4096 for Walking, Running Attr x 
df_wc=df[
      ((df.Activity=="Walking")|(df.Activity=="Running"))&(df.Accelerometer_axis=="x")&(df.Delay==1)&(df.Dimension==5)&(df.Signal_Length==4096)
          ]
df_wc
groups = df_wc.groupby("Activity")
for name, group in groups:
    plt.plot(group["Permutation Entropy"], group["Complexity"], marker="o", linestyle="", label=name)
    plt.legend()
    plt.xlabel("Permutation Entropy")
    plt.ylabel("Complexity")

# %%
#3.permutation entropy vs complexity for Delay=1, Dimension 5 and Signal Length 4096 for Walking, Running Attr y 
df_wc=df[
      ((df.Activity=="Walking")|(df.Activity=="Running"))&(df.Accelerometer_axis=="y")&(df.Delay==1)&(df.Dimension==5)&(df.Signal_Length==4096)
          ]
df_wc
groups = df_wc.groupby("Activity")
for name, group in groups:
    plt.plot(group["Permutation Entropy"], group["Complexity"], marker="o", linestyle="", label=name)
    plt.legend()
    plt.xlabel("Permutation Entropy")
    plt.ylabel("Complexity")

# %%
#3.permutation entropy vs complexity for Delay=1, Dimension 5 and Signal Length 4096 for Walking, Running Attr z 
df_wc=df[
      ((df.Activity=="Walking")|(df.Activity=="Running"))&(df.Accelerometer_axis=="z")&(df.Delay==1)&(df.Dimension==5)&(df.Signal_Length==4096)
          ]
df_wc
groups = df_wc.groupby("Activity")
for name, group in groups:
    plt.plot(group["Permutation Entropy"], group["Complexity"], marker="o", linestyle="", label=name)
    plt.legend()
    plt.xlabel("Permutation Entropy")
    plt.ylabel("Complexity")

# %%
#3.permutation entropy vs complexity for Delay=1, Dimension 6 and Signal Length 4096 for Walking, Running Attr x 
df_wc=df[
      ((df.Activity=="Walking")|(df.Activity=="Running"))&(df.Accelerometer_axis=="x")&(df.Delay==1)&(df.Dimension==6)&(df.Signal_Length==4096)
          ]
df_wc
groups = df_wc.groupby("Activity")
for name, group in groups:
    plt.plot(group["Permutation Entropy"], group["Complexity"], marker="o", linestyle="", label=name)
    plt.legend()
    plt.xlabel("Permutation Entropy")
    plt.ylabel("Complexity")

# %%
#3.permutation entropy vs complexity for Delay=1, Dimension 6 and Signal Length 4096 for Walking, Running Attr y 
df_wc=df[
      ((df.Activity=="Walking")|(df.Activity=="Running"))&(df.Accelerometer_axis=="y")&(df.Delay==1)&(df.Dimension==6)&(df.Signal_Length==4096)
          ]
df_wc
groups = df_wc.groupby("Activity")
for name, group in groups:
    plt.plot(group["Permutation Entropy"], group["Complexity"], marker="o", linestyle="", label=name)
    plt.legend()
    plt.xlabel("Permutation Entropy")
    plt.ylabel("Complexity")

# %%
#3.permutation entropy vs complexity for Delay=1, Dimension 6 and Signal Length 4096 for Walking, Running Attr z 
df_wc=df[
      ((df.Activity=="Walking")|(df.Activity=="Running"))&(df.Accelerometer_axis=="z")&(df.Delay==1)&(df.Dimension==6)&(df.Signal_Length==4096)
          ]
df_wc
groups = df_wc.groupby("Activity")
for name, group in groups:
    plt.plot(group["Permutation Entropy"], group["Complexity"], marker="o", linestyle="", label=name)
    plt.legend()
    plt.xlabel("Permutation Entropy")
    plt.ylabel("Complexity")

# %%
#4.permutation entropy vs complexity for Delay=1, Dimension 3 and Signal Length 4096 for Climbingup, ClimbingDown Attr x 
df_wc=df[
      ((df.Activity=="Climbingup")|(df.Activity=="ClimbingDown"))&(df.Accelerometer_axis=="x")&(df.Delay==1)&(df.Dimension==3)&(df.Signal_Length==4096)
          ]
df_wc
groups = df_wc.groupby("Activity")
for name, group in groups:
    plt.plot(group["Permutation Entropy"], group["Complexity"], marker="o", linestyle="", label=name,)
    plt.legend()
    plt.xlabel("Permutation Entropy")
    plt.ylabel("Complexity")

# %%
#4.permutation entropy vs complexity for Delay=1, Dimension 3 and Signal Length 4096 for Climbingup, ClimbingDown Attr y 

df_wc=df[
      ((df.Activity=="Climbingup")|(df.Activity=="ClimbingDown"))&(df.Accelerometer_axis=="y")&(df.Delay==1)&(df.Dimension==3)&(df.Signal_Length==4096)
          ]
df_wc
groups = df_wc.groupby("Activity")
for name, group in groups:
    plt.plot(group["Permutation Entropy"], group["Complexity"], marker="o", linestyle="", label=name)
    plt.legend()
    plt.xlabel("Permutation Entropy")
    plt.ylabel("Complexity")

# %%
#4.permutation entropy vs complexity for Delay=1, Dimension 3 and Signal Length 4096 for Climbingup, ClimbingDown Attr z 

df_wc=df[
      ((df.Activity=="Climbingup")|(df.Activity=="ClimbingDown"))&(df.Accelerometer_axis=="z")&(df.Delay==1)&(df.Dimension==3)&(df.Signal_Length==4096)
          ]
df_wc
groups = df_wc.groupby("Activity")
for name, group in groups:
    plt.plot(group["Permutation Entropy"], group["Complexity"], marker="o", linestyle="", label=name)
    plt.legend()
    plt.xlabel("Permutation Entropy")
    plt.ylabel("Complexity")

# %%
#4.permutation entropy vs complexity for Delay=1, Dimension 4 and Signal Length 4096 for Climbingup, ClimbingDown Attr x 

df_wc=df[
      ((df.Activity=="Climbingup")|(df.Activity=="ClimbingDown"))&(df.Accelerometer_axis=="x")&(df.Delay==1)&(df.Dimension==4)&(df.Signal_Length==4096)
          ]
df_wc
groups = df_wc.groupby("Activity")
for name, group in groups:
    plt.plot(group["Permutation Entropy"], group["Complexity"], marker="o", linestyle="", label=name)
    plt.legend()
    plt.xlabel("Permutation Entropy")
    plt.ylabel("Complexity")

# %%
#4.permutation entropy vs complexity for Delay=1, Dimension 4 and Signal Length 4096 for Climbingup, ClimbingDown Attr y 

df_wc=df[
      ((df.Activity=="Climbingup")|(df.Activity=="ClimbingDown"))&(df.Accelerometer_axis=="y")&(df.Delay==1)&(df.Dimension==4)&(df.Signal_Length==4096)
          ]
df_wc
groups = df_wc.groupby("Activity")
for name, group in groups:
    plt.plot(group["Permutation Entropy"], group["Complexity"], marker="o", linestyle="", label=name)
    plt.legend()
    plt.xlabel("Permutation Entropy")
    plt.ylabel("Complexity")

# %%
#4.permutation entropy vs complexity for Delay=1, Dimension 4 and Signal Length 4096 for Climbingup, ClimbingDown Attr z
df_wc=df[
      ((df.Activity=="Climbingup")|(df.Activity=="ClimbingDown"))&(df.Accelerometer_axis=="z")&(df.Delay==1)&(df.Dimension==4)&(df.Signal_Length==4096)
          ]
df_wc
groups = df_wc.groupby("Activity")
for name, group in groups:
    plt.plot(group["Permutation Entropy"], group["Complexity"], marker="o", linestyle="", label=name)
    plt.legend()
    plt.xlabel("Permutation Entropy")
    plt.ylabel("Complexity")

# %%
#4.permutation entropy vs complexity for Delay=1, Dimension 5 and Signal Length 4096 for Climbingup, ClimbingDown Attr x
df_wc=df[
      ((df.Activity=="Climbingup")|(df.Activity=="ClimbingDown"))&(df.Accelerometer_axis=="x")&(df.Delay==1)&(df.Dimension==5)&(df.Signal_Length==4096)
          ]
df_wc
groups = df_wc.groupby("Activity")
for name, group in groups:
    plt.plot(group["Permutation Entropy"], group["Complexity"], marker="o", linestyle="", label=name)
    plt.legend()
    plt.xlabel("Permutation Entropy")
    plt.ylabel("Complexity")

# %%
#4.permutation entropy vs complexity for Delay=1, Dimension 5 and Signal Length 4096 for Climbingup, ClimbingDown Attr y
df_wc=df[
      ((df.Activity=="Climbingup")|(df.Activity=="ClimbingDown"))&(df.Accelerometer_axis=="y")&(df.Delay==1)&(df.Dimension==5)&(df.Signal_Length==4096)
          ]
df_wc
groups = df_wc.groupby("Activity")
for name, group in groups:
    plt.plot(group["Permutation Entropy"], group["Complexity"], marker="o", linestyle="", label=name)
    plt.legend()
    plt.xlabel("Permutation Entropy")
    plt.ylabel("Complexity")

# %%
#4.permutation entropy vs complexity for Delay=1, Dimension 5 and Signal Length 4096 for Climbingup, ClimbingDown Attr z
df_wc=df[
      ((df.Activity=="Climbingup")|(df.Activity=="ClimbingDown"))&(df.Accelerometer_axis=="z")&(df.Delay==1)&(df.Dimension==5)&(df.Signal_Length==4096)
          ]
df_wc
groups = df_wc.groupby("Activity")
for name, group in groups:
    plt.plot(group["Permutation Entropy"], group["Complexity"], marker="o", linestyle="", label=name)
    plt.legend()
    plt.xlabel("Permutation Entropy")
    plt.ylabel("Complexity")

# %%
#4.permutation entropy vs complexity for Delay=1, Dimension 6 and Signal Length 4096 for Climbingup, ClimbingDown Attr x
df_wc=df[
      ((df.Activity=="Climbingup")|(df.Activity=="ClimbingDown"))&(df.Accelerometer_axis=="x")&(df.Delay==1)&(df.Dimension==6)&(df.Signal_Length==4096)
          ]
df_wc
groups = df_wc.groupby("Activity")
for name, group in groups:
    plt.plot(group["Permutation Entropy"], group["Complexity"], marker="o", linestyle="", label=name)
    plt.legend()
    plt.xlabel("Permutation Entropy")
    plt.ylabel("Complexity")

# %%
#4.permutation entropy vs complexity for Delay=1, Dimension 6 and Signal Length 4096 for Climbingup, ClimbingDown Attr y
df_wc=df[
      ((df.Activity=="Climbingup")|(df.Activity=="ClimbingDown"))&(df.Accelerometer_axis=="y")&(df.Delay==1)&(df.Dimension==6)&(df.Signal_Length==4096)
          ]
df_wc
groups = df_wc.groupby("Activity")
for name, group in groups:
    plt.plot(group["Permutation Entropy"], group["Complexity"], marker="o", linestyle="", label=name)
    plt.legend()
    plt.xlabel("Permutation Entropy")
    plt.ylabel("Complexity")

# %%
#4.permutation entropy vs complexity for Delay=1, Dimension 6 and Signal Length 4096 for Climbingup, ClimbingDown Attr z

df_wc=df[
      ((df.Activity=="Climbingup")|(df.Activity=="ClimbingDown"))&(df.Accelerometer_axis=="z")&(df.Delay==1)&(df.Dimension==6)&(df.Signal_Length==4096)
          ]
df_wc
groups = df_wc.groupby("Activity")
for name, group in groups:
    plt.plot(group["Permutation Entropy"], group["Complexity"], marker="o", linestyle="", label=name)
    plt.legend()
    plt.xlabel("Permutation Entropy")
    plt.ylabel("Complexity")
